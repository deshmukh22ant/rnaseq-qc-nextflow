# %%
# BRONZE: Read raw MultiQC JSON from S3
from pyspark.sql.functions import col, avg, count

bucket = "rnaseq-pipeline-035932132079"
s3_path = f"s3a://rnaseq-pipeline-035932132079/results/multiqc_data.json"

try:
    df_bronze = spark.read.json(s3_path)
    df_bronze.write.mode("overwrite").saveAsTable("bronze_multiqc")
    print("✅ Bronze table created")
    df_bronze.display()
except Exception as e:
    print(f"⚠️ Bronze layer error: {e}")
    print("This is expected if MultiQC output format differs. Checking structure...")
# Out:
# ⚠️ Bronze layer error: [UNAUTHORIZED_ACCESS] Unauthorized access:
# ...
